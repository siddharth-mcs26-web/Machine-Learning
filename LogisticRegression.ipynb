# %%
import numpy as np
import matplotlib.pyplot as plt
import random
random.seed(42)
X = np.random.randint(1, 10000, 100)
print(X)
Y = []
for i in X:
    if i > 3300:
        Y.append(1)
    else:
        Y.append(0)
Y = np.array(Y)
split_boundary = int(len(X)*(0.8))

X_train = X[:split_boundary]
Y_train = Y[:split_boundary]
X_test = X[split_boundary:]
Y_test = Y[split_boundary:]

def sigmoid(Z):
    return 1/(1+np.exp(-Z))

def loss(y, y_pred):
    epsilon = 1e-15
    
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    
    return -np.mean(
        y * np.log(y_pred) +
        (1 - y) * np.log(1 - y_pred)
    )

w = 0
b = 0
epochs = 1000
alpha = 0.00000001
loss_train = []
for i in range(epochs):
    Z = X_train*w + b
    y_pred = np.vectorize(sigmoid)(Z)
    error = y_pred - Y_train
    loss_train.append(loss(Y_train, y_pred))
    dw = np.mean(np.sum(error*X_train))
    db = np.mean(np.sum(error))

    w = w - alpha*dw
    b = b - alpha*db

Z = X_test*w + b
y_pred = np.vectorize(sigmoid)(Z)
predictions = []
for y in y_pred:
    if y > 0.5:
        predictions.append(1)
    else:
        predictions.append(0)

accuracy = []
for i in range(len(predictions)):
    if (predictions[i]==Y_test[i]):
        accuracy.append(1)
    else:
        accuracy.append(0)

acc = (np.sum(accuracy))/len(accuracy)
print(acc)
x_axis = [i for i in range(epochs)]
plt.plot(x_axis, loss_train)
plt.show()
# Out:
# [  33 8377 6040 9937 8964 8467 3374  792 7380  360 9820 7250 9726 3333
#  6588 6418 1385 4058 8265 5524  466 3839 5015 4638 8607  169 7685 4510
#  5357 5568 3806 6475 7594 2329 7528 8306 1998  537 8410 4705  606 8785
#  5549 1076 1524  603 9532 7036 1104 8258 7546 6657  952 7133 2090 1908
#  2661 9186  260 1880 5658 6194 3472 3371 5752  314 6916 1154 2589 9191
#  4317 9009 2876 2438 2634 9733    5 7479 4876 3889 1720 8796 9594 1100
#  5320 9001 2702    6 1950 7597 1122 9813 2725 4493 8508 2681 5878 6618
#  4761 5018]
# 0.6

# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 23.4 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 40.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 34.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 36.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
